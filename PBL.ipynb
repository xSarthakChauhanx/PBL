# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\siddh\OneDrive\Desktop\pkroject\pbl\Heart_Disease_Prediction.csv")
data
# Out:
#      Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0     70  1.0              4.0  130.0        322.0           0.0          2.0
# 1     67  0.0              3.0  115.0        564.0           0.0          2.0
# 2     57  1.0              2.0  124.0        261.0           0.0          0.0
# 3     64  1.0              4.0  128.0        263.0           0.0          0.0
# 4     74  0.0              2.0  120.0        269.0           0.0          2.0
# ..   ...  ...              ...    ...          ...           ...          ...
# 265   52  1.0              3.0  172.0        199.0           1.0          NaN
# 266   44  1.0              2.0  120.0        263.0           0.0          0.0
# 267   56  0.0              2.0  140.0        294.0           0.0          2.0
# 268   57  1.0              NaN  140.0        192.0           0.0          0.0
# 269   67  1.0              4.0  160.0        286.0           0.0          2.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      268 non-null    float64
#  2   Chest pain type          266 non-null    float64
#  3   BP                       264 non-null    float64
#  4   Cholesterol              261 non-null    float64
#  5   FBS over 120             266 non-null    float64
#  6   EKG results              263 non-null    float64
#  7   Max HR                   266 non-null    float64
#  8   Exercise angina          262 non-null    float64
#  9   ST depression            266 non-null    float64
#  10  Slope of ST              262 non-null    float64
#  11  Number of vessels fluro  263 non-null    float64
#  12  Thallium                 268 non-null    float64
#  13  Heart Disease            258 non-null    str
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Sex                         2
# Chest pain type             4
# BP                          6
# Cholesterol                 9
# FBS over 120                4
# EKG results                 7
# Max HR                      4
# Exercise angina             8
# ST depression               4
# Slope of ST                 8
# Number of vessels fluro     7
# Thallium                    2
# Heart Disease              12
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#      Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0     70  1.0              4.0  130.0        322.0           0.0          2.0
# 1     67  0.0              3.0  115.0        564.0           0.0          2.0
# 2     57  1.0              2.0  124.0        261.0           0.0          0.0
# 3     64  1.0              4.0  128.0        263.0           0.0          0.0
# 4     74  0.0              2.0  120.0        269.0           0.0          2.0
# ..   ...  ...              ...    ...          ...           ...          ...
# 265   52  1.0              3.0  172.0        199.0           1.0          NaN
# 266   44  1.0              2.0  120.0        263.0           0.0          0.0
# 267   56  0.0              2.0  140.0        294.0           0.0          2.0
# 268   57  1.0              NaN  140.0        192.0           0.0          0.0
# 269   67  1.0              4.0  160.0        286.0           0.0          2.0
#
# ...

# %%
data.fillna(data.mean(numeric_only=True), inplace=True)
# Out:
#      Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0     70  1.0         4.000000  130.0        322.0           0.0     2.000000
# 1     67  0.0         3.000000  115.0        564.0           0.0     2.000000
# 2     57  1.0         2.000000  124.0        261.0           0.0     0.000000
# 3     64  1.0         4.000000  128.0        263.0           0.0     0.000000
# 4     74  0.0         2.000000  120.0        269.0           0.0     2.000000
# ..   ...  ...              ...    ...          ...           ...          ...
# 265   52  1.0         3.000000  172.0        199.0           1.0     1.026616
# 266   44  1.0         2.000000  120.0        263.0           0.0     0.000000
# 267   56  0.0         2.000000  140.0        294.0           0.0     2.000000
# 268   57  1.0         3.169173  140.0        192.0           0.0     0.000000
# 269   67  1.0         4.000000  160.0        286.0           0.0     2.000000
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Sex                         0
# Chest pain type             0
# BP                          0
# Cholesterol                 0
# FBS over 120                0
# EKG results                 0
# Max HR                      0
# Exercise angina             0
# ST depression               0
# Slope of ST                 0
# Number of vessels fluro     0
# Thallium                    0
# Heart Disease              12
# dtype: int64

# %%
data.fillna({"Heart Disease": data["Heart Disease"].mode()[0]}, inplace=True)
# Out:
#      Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0     70  1.0         4.000000  130.0        322.0           0.0     2.000000
# 1     67  0.0         3.000000  115.0        564.0           0.0     2.000000
# 2     57  1.0         2.000000  124.0        261.0           0.0     0.000000
# 3     64  1.0         4.000000  128.0        263.0           0.0     0.000000
# 4     74  0.0         2.000000  120.0        269.0           0.0     2.000000
# ..   ...  ...              ...    ...          ...           ...          ...
# 265   52  1.0         3.000000  172.0        199.0           1.0     1.026616
# 266   44  1.0         2.000000  120.0        263.0           0.0     0.000000
# 267   56  0.0         2.000000  140.0        294.0           0.0     2.000000
# 268   57  1.0         3.169173  140.0        192.0           0.0     0.000000
# 269   67  1.0         4.000000  160.0        286.0           0.0     2.000000
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Heart Disease'] = le.fit_transform(data['Heart Disease'])

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data
# Out:
#      Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0     70  1.0         4.000000  130.0        322.0           0.0     2.000000
# 1     67  0.0         3.000000  115.0        564.0           0.0     2.000000
# 2     57  1.0         2.000000  124.0        261.0           0.0     0.000000
# 3     64  1.0         4.000000  128.0        263.0           0.0     0.000000
# 4     74  0.0         2.000000  120.0        269.0           0.0     2.000000
# ..   ...  ...              ...    ...          ...           ...          ...
# 265   52  1.0         3.000000  172.0        199.0           1.0     1.026616
# 266   44  1.0         2.000000  120.0        263.0           0.0     0.000000
# 267   56  0.0         2.000000  140.0        294.0           0.0     2.000000
# 268   57  1.0         3.169173  140.0        192.0           0.0     0.000000
# 269   67  1.0         4.000000  160.0        286.0           0.0     2.000000
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
features = [
    'Number of vessels fluro', 'Thallium', 'Slope of ST', 'ST depression',
    'Exercise angina', 'Max HR', 'EKG results', 'FBS over 120',
    'Cholesterol', 'BP', 'Chest pain type', 'Age'
]
target = 'Heart Disease'
x = data[features]
y = data[target]

# %%
x , y
# Out:
# (     Number of vessels fluro  Thallium  Slope of ST  ST depression  \
#  0                        3.0       3.0          2.0            2.4
#  1                        0.0       7.0          2.0            1.6
#  2                        0.0       7.0          1.0            0.3
#  3                        1.0       7.0          2.0            0.2
#  4                        1.0       3.0          1.0            0.2
#  ..                       ...       ...          ...            ...
#  265                      0.0       7.0          1.0            0.5
#  266                      0.0       7.0          1.0            0.0
#  267                      0.0       3.0          2.0            1.3
#  268                      0.0       6.0          2.0            0.4
#  269                      3.0       3.0          2.0            1.5
#
#       Exercise angina  Max HR  EKG results  FBS over 120  Cholesterol     BP  \
# ...

# %%
# Plot histograms for all selected features
data[features].hist(figsize=(15,10))
plt.suptitle("Distribution of Selected Features")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=data[features])
plt.xticks(rotation=45)
plt.title("Boxplot of Selected Features")
plt.show()

# %%
x.shape
# Out:
# (270, 12)

# %%
y.shape
# Out:
# (270,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

# Split into train and test (80-20)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Fit on training data and transform
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using same scaler
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn.fit(X_train_scaled, y_train)

# Make predictions
y_pred = knn.predict(X_test_scaled)

# Evaluate performance
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-Score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.8703703703703703
# Precision: 0.85
# Recall: 0.8095238095238095
# F1-Score: 0.8292682926829268

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[30  3]
#  [ 4 17]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('KNN Confusion Matrix')
plt.show()

# %%
for col in features:
    plt.figure()
    sns.boxplot(x=data['Heart Disease'], y=data[col])
    plt.title(f"{col} vs Heart Disease")
    plt.show()
